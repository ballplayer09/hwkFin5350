# %%
import options as opt
import matplotlib.pyplot as plt

# %% [markdown]
# ### __Problem 2__

# %%
spot = 100.0
strike = 95.0
rate = .08
expiry = 1
div = 0.05
vol = .30
num = 252

# %%
prices = opt.binomial_path(spot, expiry, rate, div, vol, num)
# Out:
# 0.49527558469414384

# %%
plt.plot(prices)
plt.xlabel("Day", color = "red")
plt.ylabel("Prices", color = "red")
plt.title("Simulated Prices", color = "red")
plt.xticks(color = "red")
plt.yticks(color = "red")
# Out:
# (array([ 85.,  90.,  95., 100., 105., 110., 115., 120., 125.]),
#  <a list of 9 Text yticklabel objects>)
